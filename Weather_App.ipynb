# %% [markdown]
# <a href="https://colab.research.google.com/github/AmishaOnMain/AmishaOnMain/blob/main/Weather_App.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests
import requests

url = "https://api.weatherapi.com/v1/current.json?key=e942dbeb75424295b4e94030242510&q={pune}"
response= requests.get(url)

# %%
data = response.json()
print(f"Temperature: {data['current']['temp_c']}\u00b0C")
# Out:
# Temperature: 24.3°C
